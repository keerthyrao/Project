# %% [markdown]
# **Install Required Libraries **

# %%
# !pip -q install langchain
# !pip -q install bitsandbytes==0.43.0 xformers einops
# !pip -q install datasets loralib sentencepiece
# !pip -q install pypdf
# !pip -q install accelerate

# !pip -q install sentence_transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.1/289.1 kB 19.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 kB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 17.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 MB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.2 MB/s eta 0:00:00
# ...

# %%
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 37.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 56.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 10.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install openai
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.6 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import TextLoader
from langchain.document_loaders import Docx2txtLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

# %%
import torch
import transformers

# %%
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)

# %%
from langchain import HuggingFacePipeline
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.chat_models import ChatOpenAI

# %%
import os
import sys

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# !mkdir docs

# %%
document=[]
for file in os.listdir("docs"):
  if file.endswith(".pdf"):
    pdf_path="./docs/"+file
    loader=PyPDFLoader(pdf_path)
    document.extend(loader.load())
  elif file.endswith('.docx') or file.endswith('.doc'):
    doc_path="./docs/"+file
    loader=Docx2txtLoader(doc_path)
    document.extend(loader.load())
  elif file.endswith('.txt'):
    text_path="./docs/"+file
    loader=TextLoader(text_path)
    document.extend(loader.load())

# %% [markdown]
# **Converting Document into String Format To perform Data Analysis**

# %%
# Check if document is a string or can be converted to a string
if isinstance(document, str):
    # Perform text analysis operations here
    # Make sure to remove this block when you're certain document is a string
    pass
else:
    # Convert document to string if possible
    try:
        document = str(document)
        # Perform text analysis operations here
        # Make sure to remove this block when you're certain document is a string
        pass
    except Exception as e:
        print("Error:", e)

# %% [markdown]
# **Tokenization**

# %%
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize

tokens = word_tokenize(document)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %% [markdown]
# **Word Frequency Analysis**

# %%
from collections import Counter

word_counts = Counter(tokens)
print(word_counts.most_common(10))
# Out:
# [(',', 1612), ('.', 1180), ('the', 1056), ('and', 903), ('to', 807), ('of', 653), ('in', 490), ('a', 479), (':', 433), ('\\n•', 423)]

# %% [markdown]
# **Sentiment Analysis**

# %%
from textblob import TextBlob

blob = TextBlob(document)
sentiment = blob.sentiment
print(sentiment)
# Out:
# Sentiment(polarity=0.1363089286444548, subjectivity=0.37498839821334834)

# %% [markdown]
# **Named Entity Recognition (NER)**
#
#
# *   Identifying and classifying named entities such as people, organizations, or locations.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(document)

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Missouri GPE
# Central Missouri LOC
# O. Box 800  \nWarrensburg PERSON
# MO 64093  \nTel GPE
# 660 CARDINAL
# 18:1 CARDINAL
# one CARDINAL
# you\'ll PERSON
# U.S. GPE
# World Report ORG
# Midwest LOC
# Princeton Review ORG
# Missouri GPE
# \nare ORG
# 97 percent PERCENT
# six months DATE
# \nThe Office of the President ORG
# Roger J. Best PERSON
# Ph.D. WORK_OF_ART
# \n PRODUCT
# the University of \nCentral ORG
# Missouri GPE
# 16th ORDINAL
# J. Best PERSON
# 1871 DATE
# UCM ORG
# more than 12,500 CARDINAL
# Midwest LOC
# \nPrinceton Review ORG
# U.S. News & World Report ORG
# -\ncentric PERSON
# College Faculty ORG
# U.S. News & World Report ORG
# 0 CARDINAL
# first ORDINAL
# Best PERSON
# first ORDINAL
# Georgia College ORG
# Milledgeville GPE
# D. NORP
# Florida State University ORG
# Tallahassee GPE
# today DATE
# Best PERSON
# 1995 DATE
# \nassi ORG
# the years DATE
# \ndean ORG
# three months DATE
# \nBoard GPE
# Governors NORP
# Best PERSON
# Nov. 5, 2018 DATE
# Best PERSON
# ...

# %% [markdown]
# **Topic Modeling**
#
# *   Identifying topics present in the corpus.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

vectorizer = CountVectorizer()
X = vectorizer.fit_transform([document])

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(X)

feature_names = vectorizer.get_feature_names_out()
for i, topic in enumerate(lda.components_):
    print(f"Topic {i}:")
    top_words_idx = topic.argsort()[:-10 - 1:-1]
    top_words = [feature_names[idx] for idx in top_words_idx]
    print(top_words)
# Out:
# Topic 0:
# ['00am', 'zoom', 'zone', '01', '0233', 'youths', '055', '0694', 'yoursel', '07']
# Topic 1:
# ['00am', 'zoom', 'zone', '01', '0233', 'youths', '055', '0694', 'yoursel', '07']
# Topic 2:
# ['the', 'and', 'to', 'of', 'in', 'you', 'for', 'your', 'is', 'or']
# Topic 3:
# ['00am', 'zoom', 'zone', '01', '0233', 'youths', '055', '0694', 'yoursel', '07']
# Topic 4:
# ['00am', 'zoom', 'zone', '01', '0233', 'youths', '055', '0694', 'yoursel', '07']

# %%
len(document)
# Out:
# 99

# %%
import matplotlib.pyplot as plt
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize

# Tokenization
tokens = word_tokenize(document)

# Calculate token lengths
token_lengths = [len(token) for token in tokens]

# Plot histogram of token lengths
plt.figure(figsize=(8, 6))
plt.hist(token_lengths, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Token Lengths')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from collections import Counter

# Define the keywords to ignore
ignore_keywords = ['the', 'and', 'to', 'of', 'in', 'a', 'an','will','as','from','by','can','is', 'that', 'it', 'for','\n.','you','your','or','\n','on','with','are','be','at',',','.']

# Filter out the ignore keywords from the tokens
filtered_tokens = [token for token in tokens if token.lower() not in ignore_keywords]

# Word Frequency Analysis
word_counts = Counter(filtered_tokens)
common_words = word_counts.most_common(20)  # Get the 20 most common words

# Exclude the first 7 most common words
common_words = common_words[7:]

# Extract words and frequencies
words, frequencies = zip(*common_words)

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(words, frequencies, color='skyblue')
plt.title('Top 10 Most Common Words (Excluding Ignored Keywords and First 7)')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(document)

# Extract named entity labels
ner_labels = [ent.label_ for ent in doc.ents]

# Plot histogram of named entity labels
plt.figure(figsize=(8, 6))
plt.hist(ner_labels, bins=20, color='skyblue', edgecolor='black')
plt.title('Named Entity Recognition (NER) Distribution')
plt.xlabel('NER Label')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)

# %%
document_splitter=CharacterTextSplitter(separator='\n', chunk_size=500, chunk_overlap=100)
document_chunks=document_splitter.split_documents(document)
len(document_chunks)
# Out:
# 531

# %%
os.environ["OPENAI_API_KEY"]="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"

# %%
embeddings = OpenAIEmbeddings()
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x7b3738df8190>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x7b3731a6a440>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='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', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None)

# %%
vectordb=Chroma.from_documents(document_chunks,embedding=embeddings, persist_directory='./data')

# %%
vectordb.persist()

# %%
llm=ChatOpenAI(temperature=0.5, model_name='gpt-3.5-turbo')

# %%
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x7b3731dae6e0>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x7b3738d073d0>, temperature=0.5, openai_api_key='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', openai_proxy='')

# %%
memory=ConversationBufferMemory(memory_key='chat_history', return_messages=True)

# %%
#Create our Q/A Chain
pdf_qa=ConversationalRetrievalChain.from_llm(llm=llm,
                                             retriever=vectordb.as_retriever(search_kwargs={'k':6}),
                                             verbose=False, memory=memory)

# %%
result=pdf_qa({"question":"tell me about sai aditya"})

# %%
results = {
"question":"tell me about sai aditya"
"chat_history":[
0:"HumanMessage(content='tell me about sai aditya')"
1:"AIMessage(content="Sai Aditya is a student pursuing a Master's in Computer Science at the University of Central Missouri with a specialization in Data Science. They completed their Bachelor's in Computer Science from Prakasam Engineering College in India. Sai Aditya has skills in Python, Machine Learning, Deep Learning, NLP, AWS, GCP, Docker, Git, and more. They have experience in data science internships, including Python programming, data scraping, data cleaning, and implementing machine learning algorithms. Sai Aditya has a passion for learning and exploring new concepts.")"
]
"answer":"Sai Aditya is a student pursuing a Master's in Computer Science at the University of Central Missouri with a specialization in Data Science. They completed their Bachelor's in Computer Science from Prakasam Engineering College in India. Sai Aditya has skills in Python, Machine Learning, Deep Learning, NLP, AWS, GCP, Docker, Git, and more. They have experience in data science internships, including Python programming, data scraping, data cleaning, and implementing machine learning algorithms. Sai Aditya has a passion for learning and exploring new concepts."
}

results["a"]

# %%
result['answer']
# Out:
# "Sai Aditya is currently pursuing a Master's in Computer Science with a specialization in Data Science at the University of Central Missouri in the USA. They completed their Bachelor's in Computer Science at Prakasam Engineering College in Andhra Pradesh, India. Sai Aditya has skills in Python, Machine Learning, Deep Learning, NLP, AWS, GCP, Docker, Git, and more. They have experience in data science through internships where they worked on Python programming, data scraping, data cleaning, and implementing machine learning algorithms with high accuracy. Additionally, Sai Aditya has a keen interest in learning and exploring new concepts."

# %%
print('---------------------------------------------------------------------------------')
print('Welcome to the DocBot. You are now ready to start interacting with your documents')
print('---------------------------------------------------------------------------------')

while True:
  query=input(f"Prompt:")
  if query == "exit" or query == "quit" or query == "q" or query == "f":
    print('Exiting')
    sys.exit()
  if query == '':
    continue
  result = pdf_qa({"question": query})
  print(f"Answer: " + result["answer"])
# Out:
# ---------------------------------------------------------------------------------
# Welcome to the DocBot. You are now ready to start interacting with your documents
# ---------------------------------------------------------------------------------
# Prompt:hello how are you
# Answer: I don't know.
# Prompt:where is university located
# Answer: The University of Central Missouri is located in Warrensburg, Missouri. Additionally, they have a campus location in Lee's Summit, which is 20 miles from Kansas City.
# Prompt:how to reach there
# Answer: You can reach the University of Central Missouri in Warrensburg, Missouri, by contacting them at the following address and phone number:
#
# University of Central Missouri
# P. O. Box 800
# Warrensburg, MO 64093
# Tel: (660) 543-4111
#
# The main campus is located in Warrensburg, about 50 miles southeast of Kansas City, Missouri.
# Prompt:q
# Exiting
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# ...
